# %% [markdown]
# # Домашнее задание: Базовые типы данных

# %% [markdown]
# ## Задание 1: Зеркальное отражение цифр
#
# Пользователь вводит пятизначное число. Программа должна зеркально отразить три центральные цифры. Первая и последняя остаются на местах.
#
# <br>
#
# **Примеры:**
# * `23456 -> 25436`
# * `30789 -> 38709`

# %%
user_input = input()
center = user_input[1:4]
reserved_center = center[::-1]
new_user_input = user_input[0] + reserved_center + user_input[-1]
print(new_user_input)

# %% [markdown]
# ## Задание 2: Подсчет выходных до отпуска
#
# Пользователь вводит сколько дней осталось до ближайшего отпуска. Программа должна вывести количество выходных дней до отпуска, если учесть, что выходные это суббота и воскресенье, сегодня понедельник и праздники мы не учитываем.
#
# <br>
#
# **Примеры:**
# * `4  -> 0`
# * `6  -> 1`
# * `14 -> 4`

# %%
n = int(input("Введите количество дней до отпуска: "))
weekends = 0
for day in range(1, n + 1):
    day_of_week = (day - 1) % 7 + 1
    if day_of_week == 6 or day_of_week == 7:
        weekends += 1

print(weekends)
# Out:
# 12

# %% [markdown]
# ## Задание 3: Плитка шоколада
#
# Пользователь вводит длину и ширину плитки шоколада, а также размер куска, который хочет отломить. Программа должна вычислить - можно ли совершить подобный разлом или нет, если учесть, что ломать можно только по прямой.
#
# <br>
#
# **Примеры:**
# * `3, 4, 6  -> True`
# * `5, 7, 8  -> False`
# * `4, 5, 12 -> True`

# %%
length = int(input("Введите длину:"))
width =int(input("Введите ширину:"))
s_shoco =int(input("Ведите площадь куска:" ))
if s_shoco<width*length and (s_shoco%width==0 or s_shoco%length==0):
    print ("Можно сломать по прямой")
else:
    print("Нельзя сломать по прямой")

# %% [markdown]
# ## Задание 4: Римские числа
#
# Пользователь вводит целое положительное число, программа должна вернуть строку в виде римского числа.
#
# <br>
#
# **Примеры:**
# * `3   -> III`
# * `15  -> XV`
# * `234 -> CCXXXIV`

# %%
user_input= int(input("Введите число:"))
roman_table = [ (1000, "M"),  (900,  "CM"), (500,  "D"),  (400,  "CD"),  (100,  "C"),  (90,   "XC"),  (50,   "L"),
    (40,   "XL"),    (10,   "X"),    (9,    "IX"),    (5,    "V"),    (4,    "IV"),    (1,    "I")]
result=""
for value, symbol in roman_table:
    while user_input>=value:
        result = result+symbol
        user_input = user_input - value
print(result)

# %% [markdown]
# ## Задание 5: Проверка на вещественное число
#
# Пользователь вводит данные, проверить - являются ли они положительным вещественным числом. Не использовать встроенные функции для проверки, только методы данных и конструкцию IF. (Дополнительное задание, по желанию - проверка на отрицательные вещественные числа)
#
# <br>
#
# **Примеры:**
# * `5.6  -> True`
# * `.78  -> True`
# * `.67. -> False`
# * `5    -> True`

# %%
result_type = "число"
result_znak = "положительное"
tochka_count = 0

user_input= input("Введите число:")
#проверяем число ли это вообще 
if user_input[0] == "-" :
    result_znak = "отрицательное"
if (user_input[0] !="." and user_input[0] !="-") and (user_input[0] <"0" or user_input[0]>"9"):
    result_type = "не число"

if len(user_input)>1:
    for i in range(len(user_input)):
        if i>1:
            if user_input[i] != "." and (user_input[i] < "0" or user_input[i] > "9"):
                result_type = "не число"
#считаем сколько точек
for letter in user_input:
    if letter == ".":
        tochka_count += 1
#выводим результаты
if tochka_count > 1:
    result_type = "не число"
if result_type == "число":
    print ("вы ввели число")
    if result_znak == ("отрицательное"):
        print ("оно отрицательное")
else:
    print ("это не вещественное число")
